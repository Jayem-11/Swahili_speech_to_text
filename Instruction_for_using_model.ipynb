# %%
# Install necessary packages
# !pip install --upgrade datasets accelerate
# !pip install transformers jiwer evaluate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.7/493.7 kB 17.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.4/261.4 kB 23.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 0.22.0
#     Uninstalling accelerate-0.22.0:
#       Successfully uninstalled accelerate-0.22.0
#   Attempting uninstall: datasets
#     Found existing installation: datasets 2.1.0
#     Uninstalling datasets-2.1.0:
#       Successfully uninstalled datasets-2.1.0
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 10.1 MB/s eta 0:00:00
# ...

# %%
# Check the device type
import torch 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# ## Hugging Face

# %% [markdown]
# log in to hugging face with your token

# %%
from huggingface_hub import login

# %%
from kaggle_secrets import UserSecretsClient
secret_label = "hf"
secret_value = UserSecretsClient().get_secret(secret_label)

# %%
login(secret_value)
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %% [markdown]
# ## Feature Extractor, Tokenizer, Processor

# %%
from transformers import WhisperForConditionalGeneration, WhisperProcessor
from transformers import WhisperFeatureExtractor, WhisperTokenizer
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
#load feature_extractor
feature_extractor = WhisperFeatureExtractor.from_pretrained("openai/whisper-small")

#load tokenizer
tokenizer = WhisperTokenizer.from_pretrained("openai/whisper-small", language="Swahili", task="transcribe")

#load processor
processor = WhisperProcessor.from_pretrained("Jayem-11/whisper-small-swahili-3")

# %% [markdown]
# ## Model

# %%
# Load the final model from huggingface
model = WhisperForConditionalGeneration.from_pretrained("Jayem-11/whisper-small-swahili-3",use_auth_token=True).to(device)
forced_decoder_ids = processor.get_decoder_prompt_ids(language="sw", task="transcribe")
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py:2351: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# ...
# /opt/conda/lib/python3.10/site-packages/transformers/utils/hub.py:374: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# ...
